# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load the Data

# %%
df = pd.read_csv("C:/Users/keshi/Downloads/archive (1)/Output_file1/EDA.csv")

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N  Cluster
# 0                44           1233                    1        0
# 1                59           3088                    1        0
# 2                48           3374                    1        0
# 3                10           1177                    1        0
# 4                46           2484                    1        0

# %% [markdown]
# # Label Encoding

# %%
df1 = df.copy()
df1
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# 2                    2                  183                4
# 3                    3                  176                4
# 4                    2                  184                3
# ...                ...                  ...              ...
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 0                    low      F                44           1233
# 1                    low      M                59           3088
# 2                    low      M                48           3374
# 3                 medium      M                10           1177
# 4                 medium      F                46           2484
# ...                  ...    ...               ...            ...
# 10994             medium      F                 1           1538
# 10995             medium      F                 6           1247
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N  Cluster
# 0                        1        0
# 1                        1        0
# 2                        1        0
# 3                        1        0
# 4                        1        0
# ...                    ...      ...
# 10994                    1        2
# 10995                    0        2
# 10996                    0        2
# 10997                    0        2
# 10998                    0        1
#
# [10999 rows x 13 columns]

# %%
df1 = pd.get_dummies(df1,columns=['Mode_of_Shipment','Product_importance','Gender'], drop_first=True)
df1
# Out:
#           ID Warehouse_block  Customer_care_calls  Customer_rating  \
# 0          1               D                    4                2
# 1          2               F                    4                5
# 2          3               A                    2                2
# 3          4               B                    3                3
# 4          5               C                    2                2
# ...      ...             ...                  ...              ...
# 10994  10995               A                    4                1
# 10995  10996               B                    4                1
# 10996  10997               C                    5                4
# 10997  10998               F                    5                2
# 10998  10999               D                    2                5
#
#        Cost_of_the_Product  Prior_purchases  Discount_offered  Weight_in_gms  \
# 0                      177                3                44           1233
# 1                      216                2                59           3088
# 2                      183                4                48           3374
# 3                      176                4                10           1177
# 4                      184                3                46           2484
# ...                    ...              ...               ...            ...
# 10994                  252                5                 1           1538
# 10995                  232                5                 6           1247
# 10996                  242                5                 4           1155
# 10997                  223                6                 2           1210
# 10998                  155                5                 6           1639
#
#        Reached.on.Time_Y.N  Cluster  Mode_of_Shipment_Road  \
# 0                        1        0                  False
# 1                        1        0                  False
# 2                        1        0                  False
# 3                        1        0                  False
# 4                        1        0                  False
# ...                    ...      ...                    ...
# 10994                    1        2                  False
# 10995                    0        2                  False
# 10996                    0        2                  False
# 10997                    0        2                  False
# 10998                    0        1                  False
#
#        Mode_of_Shipment_Ship  Product_importance_low  \
# 0                      False                    True
# 1                      False                    True
# 2                      False                    True
# 3                      False                   False
# 4                      False                   False
# ...                      ...                     ...
# 10994                   True                   False
# 10995                   True                   False
# 10996                   True                    True
# 10997                   True                   False
# 10998                   True                    True
#
#        Product_importance_medium  Gender_M
# 0                          False     False
# 1                          False      True
# 2                          False      True
# 3                           True      True
# 4                           True     False
# ...                          ...       ...
# 10994                       True     False
# 10995                       True     False
# 10996                      False     False
# 10997                       True      True
# 10998                      False     False
#
# [10999 rows x 15 columns]

# %%
lE = LabelEncoder()
df1['Warehouse_block']=lE.fit_transform(df1['Warehouse_block'])
df1
# Out:
#           ID  Warehouse_block  Customer_care_calls  Customer_rating  \
# 0          1                3                    4                2
# 1          2                4                    4                5
# 2          3                0                    2                2
# 3          4                1                    3                3
# 4          5                2                    2                2
# ...      ...              ...                  ...              ...
# 10994  10995                0                    4                1
# 10995  10996                1                    4                1
# 10996  10997                2                    5                4
# 10997  10998                4                    5                2
# 10998  10999                3                    2                5
#
#        Cost_of_the_Product  Prior_purchases  Discount_offered  Weight_in_gms  \
# 0                      177                3                44           1233
# 1                      216                2                59           3088
# 2                      183                4                48           3374
# 3                      176                4                10           1177
# 4                      184                3                46           2484
# ...                    ...              ...               ...            ...
# 10994                  252                5                 1           1538
# 10995                  232                5                 6           1247
# 10996                  242                5                 4           1155
# 10997                  223                6                 2           1210
# 10998                  155                5                 6           1639
#
#        Reached.on.Time_Y.N  Cluster  Mode_of_Shipment_Road  \
# 0                        1        0                  False
# 1                        1        0                  False
# 2                        1        0                  False
# 3                        1        0                  False
# 4                        1        0                  False
# ...                    ...      ...                    ...
# 10994                    1        2                  False
# 10995                    0        2                  False
# 10996                    0        2                  False
# 10997                    0        2                  False
# 10998                    0        1                  False
#
#        Mode_of_Shipment_Ship  Product_importance_low  \
# 0                      False                    True
# 1                      False                    True
# 2                      False                    True
# 3                      False                   False
# 4                      False                   False
# ...                      ...                     ...
# 10994                   True                   False
# 10995                   True                   False
# 10996                   True                    True
# 10997                   True                   False
# 10998                   True                    True
#
#        Product_importance_medium  Gender_M
# 0                          False     False
# 1                          False      True
# 2                          False      True
# 3                           True      True
# 4                           True     False
# ...                          ...       ...
# 10994                       True     False
# 10995                       True     False
# 10996                      False     False
# 10997                       True      True
# 10998                      False     False
#
# [10999 rows x 15 columns]

# %%
x = df1.drop(['Reached.on.Time_Y.N','ID'], axis=1)
x
# Out:
#        Warehouse_block  Customer_care_calls  Customer_rating  \
# 0                    3                    4                2
# 1                    4                    4                5
# 2                    0                    2                2
# 3                    1                    3                3
# 4                    2                    2                2
# ...                ...                  ...              ...
# 10994                0                    4                1
# 10995                1                    4                1
# 10996                2                    5                4
# 10997                4                    5                2
# 10998                3                    2                5
#
#        Cost_of_the_Product  Prior_purchases  Discount_offered  Weight_in_gms  \
# 0                      177                3                44           1233
# 1                      216                2                59           3088
# 2                      183                4                48           3374
# 3                      176                4                10           1177
# 4                      184                3                46           2484
# ...                    ...              ...               ...            ...
# 10994                  252                5                 1           1538
# 10995                  232                5                 6           1247
# 10996                  242                5                 4           1155
# 10997                  223                6                 2           1210
# 10998                  155                5                 6           1639
#
#        Cluster  Mode_of_Shipment_Road  Mode_of_Shipment_Ship  \
# 0            0                  False                  False
# 1            0                  False                  False
# 2            0                  False                  False
# 3            0                  False                  False
# 4            0                  False                  False
# ...        ...                    ...                    ...
# 10994        2                  False                   True
# 10995        2                  False                   True
# 10996        2                  False                   True
# 10997        2                  False                   True
# 10998        1                  False                   True
#
#        Product_importance_low  Product_importance_medium  Gender_M
# 0                        True                      False     False
# 1                        True                      False      True
# 2                        True                      False      True
# 3                       False                       True      True
# 4                       False                       True     False
# ...                       ...                        ...       ...
# 10994                   False                       True     False
# 10995                   False                       True     False
# 10996                    True                      False     False
# 10997                   False                       True      True
# 10998                    True                      False     False
#
# [10999 rows x 13 columns]

# %%
y = df1['Reached.on.Time_Y.N']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10994    1
# 10995    0
# 10996    0
# 10997    0
# 10998    0
# Name: Reached.on.Time_Y.N, Length: 10999, dtype: int64

# %% [markdown]
# # Splitting Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Scaling Data

# %%
scaler=StandardScaler()
x_train_scaled =scaler.fit_transform(x_train)
x_train=pd.DataFrame(x_train_scaled,columns=x.columns)
x_train
# Out:
#       Warehouse_block  Customer_care_calls  Customer_rating  \
# 0           -0.894636             2.546375         0.709617
# 1            1.117773            -0.058764        -1.416196
# 2           -0.223833            -0.058764        -1.416196
# 3            1.117773            -0.927144        -1.416196
# 4           -0.894636             0.809616         1.418221
# ...               ...                  ...              ...
# 7694        -0.223833            -0.927144         1.418221
# 7695         1.117773             0.809616         1.418221
# 7696        -1.565439            -0.058764        -0.707592
# 7697        -1.565439             0.809616         0.001012
# 7698        -0.223833            -0.058764         0.001012
#
#       Cost_of_the_Product  Prior_purchases  Discount_offered  Weight_in_gms  \
# 0                1.476283         0.268305         -0.453434      -1.113175
# 1               -1.564598        -1.039087          3.128587      -1.314043
# 2                0.069617        -1.039087         -0.206398       0.502928
# 3               -0.819893        -1.039087         -0.762229      -1.217578
# 4                0.772950        -1.039087         -0.576952       1.198945
# ...                   ...              ...               ...            ...
# 7694             1.331480        -1.039087         -0.391675       0.607941
# 7695            -0.488912         0.268305         -0.268157       1.039594
# 7696            -1.523226        -1.039087         -0.700470       1.331433
# 7697            -1.378422         1.575697          1.337577      -1.596113
# 7698            -1.150873        -0.385391         -0.700470       0.556045
#
#        Cluster  Mode_of_Shipment_Road  Mode_of_Shipment_Ship  \
# 0     1.433839              -0.435204               0.689543
# 1    -1.543271              -0.435204              -1.450236
# 2    -0.054716              -0.435204               0.689543
# 3    -0.054716              -0.435204               0.689543
# 4    -0.054716              -0.435204               0.689543
# ...        ...                    ...                    ...
# 7694 -0.054716               2.297775              -1.450236
# 7695 -0.054716               2.297775              -1.450236
# 7696 -0.054716              -0.435204               0.689543
# 7697 -1.543271              -0.435204               0.689543
# 7698 -0.054716              -0.435204              -1.450236
#
#       Product_importance_low  Product_importance_medium  Gender_M
# 0                   1.035841                  -0.870496   0.99961
# 1                  -0.965399                   1.148771  -1.00039
# 2                   1.035841                  -0.870496  -1.00039
# 3                   1.035841                  -0.870496   0.99961
# 4                   1.035841                  -0.870496   0.99961
# ...                      ...                        ...       ...
# 7694                1.035841                  -0.870496  -1.00039
# 7695               -0.965399                   1.148771  -1.00039
# 7696               -0.965399                   1.148771  -1.00039
# 7697               -0.965399                   1.148771  -1.00039
# 7698               -0.965399                  -0.870496  -1.00039
#
# [7699 rows x 13 columns]

# %%
x_test_scaled = scaler.transform(x_test)
x_test=pd.DataFrame(x_test_scaled,columns=x.columns)
x_test
# Out:
#       Warehouse_block  Customer_care_calls  Customer_rating  \
# 0            1.117773            -0.058764         1.418221
# 1           -1.565439            -0.927144        -1.416196
# 2            1.117773            -0.927144        -0.707592
# 3            0.446970             0.809616        -1.416196
# 4           -0.894636             0.809616         0.709617
# ...               ...                  ...              ...
# 3295        -1.565439            -0.927144        -1.416196
# 3296         1.117773            -0.927144         1.418221
# 3297        -0.223833            -0.927144         0.001012
# 3298        -0.223833            -0.058764        -0.707592
# 3299         1.117773             0.809616         1.418221
#
#       Cost_of_the_Product  Prior_purchases  Discount_offered  Weight_in_gms  \
# 0                0.110990        -0.385391          0.781746      -0.958708
# 1                0.193735        -0.385391         -0.453434       1.189787
# 2                0.090303         0.268305         -0.638711       0.255659
# 3               -1.047442         0.922001         -0.762229       0.640300
# 4                0.379911        -1.039087          1.893407      -0.735250
# ...                   ...              ...               ...            ...
# 3295            -0.675089         0.268305         -0.268157       1.284421
# 3296             1.228048        -0.385391         -0.391675       0.510254
# 3297             1.103931        -1.039087         -0.453434       0.292291
# 3298             1.290107         0.268305          0.781746      -0.244375
# 3299            -1.130187        -1.039087         -0.329916       0.728828
#
#        Cluster  Mode_of_Shipment_Road  Mode_of_Shipment_Ship  \
# 0    -1.543271              -0.435204               0.689543
# 1    -0.054716               2.297775              -1.450236
# 2    -0.054716              -0.435204              -1.450236
# 3    -0.054716              -0.435204              -1.450236
# 4    -1.543271              -0.435204               0.689543
# ...        ...                    ...                    ...
# 3295 -0.054716              -0.435204               0.689543
# 3296 -0.054716              -0.435204               0.689543
# 3297 -0.054716              -0.435204               0.689543
# 3298  1.433839              -0.435204               0.689543
# 3299 -0.054716              -0.435204              -1.450236
#
#       Product_importance_low  Product_importance_medium  Gender_M
# 0                  -0.965399                  -0.870496   0.99961
# 1                   1.035841                  -0.870496  -1.00039
# 2                   1.035841                  -0.870496  -1.00039
# 3                   1.035841                  -0.870496  -1.00039
# 4                  -0.965399                   1.148771  -1.00039
# ...                      ...                        ...       ...
# 3295               -0.965399                   1.148771   0.99961
# 3296               -0.965399                  -0.870496  -1.00039
# 3297                1.035841                  -0.870496   0.99961
# 3298                1.035841                  -0.870496  -1.00039
# 3299                1.035841                  -0.870496  -1.00039
#
# [3300 rows x 13 columns]
